# %%
# %cd "/content/drive/My Drive/Colab Notebooks/Thesis/KGEmb_master"
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/Thesis/KGEmb_master
# data	  examples	   models      README.md	 run.py      test.py
# datasets  KGEmb-run.ipynb  optimizers  requirements.txt  set_env.sh  utils

# %%
#!/bin/bash
# !source set_env.sh
# !pip install numpy
# !pip install torch
# !pip install tqdm

# %%
from pathlib import Path
import pkg_resources
print(Path(pkg_resources.resource_filename('KGEmb_master','data/')))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in get_provider(moduleOrReq)
#     343     try:
# --> 344         module = sys.modules[moduleOrReq]
#     345     except KeyError:
#
# KeyError: 'KGEmb_master'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-459740461e03> in <module>()
#       1 from pathlib import Path
#       2 import pkg_resources
# ----> 3 print(Path(pkg_resources.resource_filename('KGEmb_master','data/')))
#
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in resource_filename(self, package_or_requirement, resource_name)
#    1128     def resource_filename(self, package_or_requirement, resource_name):
# ...

# %%
# !source datasets/download.sh
# !python datasets/process.py
# Out:
# --2021-04-23 18:32:09--  https://dl.fbaipublicfiles.com/kbc/data.tar.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.75.142, 104.22.74.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13696853 (13M) [application/gzip]
# Saving to: ‘data.tar.gz’
#
# data.tar.gz         100%[===================>]  13.06M  4.46MB/s    in 2.9s
#
# 2021-04-23 18:32:12 (4.46 MB/s) - ‘data.tar.gz’ saved [13696853/13696853]
#
# data/
# data/FB15K/
# data/FB15K/license.txt
# data/FB15K/test
# data/FB15K/train
# data/FB15K/valid
# data/FB237/
# data/FB237/license.docx
# data/FB237/test
# data/FB237/train
# data/FB237/valid
# data/WN/
# data/WN/license.txt
# data/WN/test
# data/WN/train
# data/WN/valid
# data/WN18RR/
# data/WN18RR/license.txt
# data/WN18RR/test
# data/WN18RR/train
# data/WN18RR/valid
# data/YAGO3-10/
# data/YAGO3-10/license.txt
# ...

# %%
# !python run.py --dataset WN18RR --model DE  --rank 32 --regularizer N3  --reg 0.0001  --optimizer Adagrad \
--max_epochs 100  --patience 15  --valid 5  --batch_size 100  --neg_sample_size 700  --init_size 0.001  --learning_rate 0.001  --gamma 0.0  --bias learn  --dtype single --double_neg  --cuda_n 0
